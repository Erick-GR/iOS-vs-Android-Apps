# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import *

# %%
df=pd.read_csv('Applestore.csv')
df.drop_duplicates("id", inplace=True)
df=df.iloc[:,1:16]
df=df[['id','track_name','size_bytes','currency','price','rating_count_tot','user_rating','prime_genre']]
df
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# 13     284847138                   Bank of America - Mobile Banking
# 14     284862767                                           FreeCell
# 15     284876795             TripAdvisor Hotels Flights Restaurants
# 16     284882215                                           Facebook
# 17     284910350     Yelp - Nearby Restaurants, Shopping & Services
# 18     284993459  Shazam - Discover music, artists, videos & lyrics
# 19     285005463                      Crash Bandicoot Nitro Kart 3D
# 20     285946052                                             iQuran
# 21     285994151                                        :) Sudoku +
# 22     286058814    Yahoo Sports - Teams, Scores, News & Highlights
# 23     286070473                          Mileage Log | Fahrtenbuch
# 24     286799607                        Cleartune - Chromatic Tuner
# 25     286906691          Lifesum – Inspiring healthy lifestyle app
# 26     286911400                                           Hangman.
# 27     288113403      iTranslate - Language Translator & Dictionary
# 28     288120394                                           TouchOSC
# 29     288419283                                         RadarScope
# ...          ...                                                ...
# 7167  1182265441                      脱出ゲーム　わたしをみつけて　-おじいさんとわたしの物語-
# 7168  1182331762                      Escape from the frigid Igloo.
# 7169  1182568288        Talking Santa - Video santa claus calls you
# 7170  1183234072                                          CTFxCmoji
# 7171  1183260922                    Room Escape Game - Santa's Room
# 7172  1183548754                               Rescue the Enchanter
# 7173  1183709176                                 My Diary - 你的名字非官方
# 7174  1183856228  VR Thrills: Roller Coaster 360 (Google Cardboard)
# 7175  1183986102   Santa Kids Hair Salon - Christmas Makeover Games
# 7176  1184711626                                 Human Juggling Cup
# 7177  1184800011                           Again - room escape game
# 7178  1185209084                                  Saloons Unleashed
# 7179  1185328193             Fam — Group video calling for iMessage
# 7180  1185365336                   Laurie Hernandez the Human Emoji
# 7181  1185428381                                               剑倚手游
# 7182  1185538497                                  camera for filter
# 7183  1185580782                                    Survivalcraft 2
# 7184  1185731859                                    剑客情缘-高爆率高掉落天天疯玩
# 7185  1185777521                                     问仙奇遇-新玩法新套装嗨到爆
# 7186  1186108496                 脱出ゲーム - 書道教室 -  "漢字"の謎に満ちた部屋からの 脱出
# 7187  1186126548                          Escape Game: illumination
# 7188  1186384912       Demolition Derby Virtual Reality (VR) Racing
# 7189  1187128255                         飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）
# 7190  1187279979                       Add-Ons Studio for Minecraft
# 7191  1187282363                         Plead the Fifth - The Game
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes currency  price  rating_count_tot  user_rating  \
# 0      100788224      USD   3.99             21292          4.0
# 1      158578688      USD   0.00            161065          4.0
# 2      100524032      USD   0.00            188583          3.5
# 3      128512000      USD   0.00            262241          4.0
# 4       92774400      USD   0.00            985920          4.5
# 5       10485713      USD   0.99              8253          4.0
# 6      227795968      USD   0.00            119487          4.0
# 7      130242560      USD   0.00           1126879          4.0
# 8       49250304      USD   9.99              1117          4.5
# 9       70023168      USD   3.99              7885          4.0
# 10      49618944      USD   4.99             76720          4.5
# 11     227547136      USD   7.99            105776          3.5
# 12     179979264      USD   0.00            479440          3.5
# 13     160925696      USD   0.00            119773          3.5
# 14      55153664      USD   4.99              6340          4.5
# 15     207907840      USD   0.00             56194          4.0
# 16     389879808      USD   0.00           2974676          3.5
# 17     167407616      USD   0.00            223885          4.0
# 18     147093504      USD   0.00            402925          4.0
# 19      10735026      USD   2.99             31456          4.0
# 20      70707916      USD   1.99              2929          4.5
# 21       6169600      USD   2.99             11447          5.0
# 22     130583552      USD   0.00            137951          4.0
# 23      71203840      USD   5.99                 8          4.5
# 24      11423008      USD   3.99              3241          4.0
# 25     188017664      USD   0.00              5795          3.5
# 26       4765696      USD   0.00             42316          3.0
# 27     287933440      USD   0.00            123215          3.5
# 28       4263936      USD   4.99               782          4.0
# 29     172772352      USD   9.99              3449          4.0
# ...          ...      ...    ...               ...          ...
# 7167   177498112      USD   0.00                 1          1.0
# 7168    89188352      USD   0.00                 3          4.0
# 7169    32685056      USD   2.99                 9          3.0
# 7170    26077184      USD   0.00                39          5.0
# 7171   143346688      USD   0.00                10          5.0
# 7172   242505728      USD   3.99                55          4.5
# 7173    18164736      USD   0.99                 0          0.0
# 7174   169535488      USD   0.00                14          4.0
# 7175    64244736      USD   0.00                41          4.5
# 7176   184324096      USD   0.00                 0          0.0
# 7177    33946624      USD   0.00                11          4.0
# 7178   327731200      USD   0.99                 0          0.0
# 7179   113382400      USD   0.00               279          3.5
# 7180    94008320      USD   0.00                26          5.0
# 7181   178160640      USD   0.99                 0          0.0
# 7182     9362432      USD   0.00                 0          0.0
# 7183    57349120      USD   3.99               292          4.0
# 7184   171944960      USD   0.00                 0          0.0
# 7185   208026624      USD   0.99                 0          0.0
# 7186    85580800      USD   0.00                 1          2.0
# 7187    52342784      USD   0.00                23          4.5
# 7188   168774656      USD   0.00                18          4.0
# 7189   537462784      USD   0.99                 0          0.0
# 7190    22999040      USD   2.99                97          3.0
# 7191    27853824      USD   2.99                11          4.0
# 7192   126644224      USD   0.00               142          4.5
# 7193   120760320      USD   0.00                30          4.5
# 7194   111322112      USD   1.99                15          4.5
# 7195    97235968      USD   0.00                85          4.5
# 7196    90898432      USD   0.00                 3          5.0
#
#             prime_genre
# 0                 Games
# 1          Productivity
# 2               Weather
# 3              Shopping
# 4             Reference
# 5                 Games
# 6               Finance
# 7                 Music
# 8             Utilities
# 9                 Games
# 10                Games
# 11                Games
# 12            Utilities
# 13              Finance
# 14                Games
# 15               Travel
# 16    Social Networking
# 17               Travel
# 18                Music
# 19                Games
# 20            Reference
# 21                Games
# 22               Sports
# 23             Business
# 24                Music
# 25     Health & Fitness
# 26                Games
# 27         Productivity
# 28                Music
# 29              Weather
# ...                 ...
# 7167              Games
# 7168              Games
# 7169      Entertainment
# 7170  Social Networking
# 7171              Games
# 7172              Games
# 7173          Utilities
# 7174              Games
# 7175              Games
# 7176              Games
# 7177              Games
# 7178              Games
# 7179  Social Networking
# 7180          Utilities
# 7181              Games
# 7182      Photo & Video
# 7183              Games
# 7184              Games
# 7185              Games
# 7186              Games
# 7187              Games
# 7188              Games
# 7189              Games
# 7190              Games
# 7191              Games
# 7192              Games
# 7193              Games
# 7194          Utilities
# 7195              Games
# 7196              Games
#
# [7197 rows x 8 columns]

# %%
df.dropna(how='any')
df['prime_genre']=df['prime_genre'].replace('Book','Book & Reference')
df['prime_genre']=df['prime_genre'].replace('Reference','Book & Reference')
#Review if there are any invalid information
Categoria=df.groupby(['prime_genre']).count().reset_index()
#df.groupby(['price']).count()
#Categoria['prime_genre']

Categorias=Categoria['prime_genre']
Categorias=Categorias.replace('Book & Reference','Book_&_Reference')
Categorias=Categorias.replace('Food & Drink','Food_&_Drink')
Categorias=Categorias.replace('Health & Fitness','Health_&_Fitness')
Categorias=Categorias.replace('Photo & Video','Photo_&_Video')
Categorias=Categorias.replace('Social Networking','Social_Networking')

Categorias
# Out:
# 0      Book_&_Reference
# 1              Business
# 2              Catalogs
# 3             Education
# 4         Entertainment
# 5               Finance
# 6          Food_&_Drink
# 7                 Games
# 8      Health_&_Fitness
# 9             Lifestyle
# 10              Medical
# 11                Music
# 12           Navigation
# 13                 News
# 14        Photo_&_Video
# 15         Productivity
# 16             Shopping
# 17    Social_Networking
# 18               Sports
# 19               Travel
# 20            Utilities
# 21              Weather
# Name: prime_genre, dtype: object

# %%
Base = automap_base()

db = "apple_db"
engine = create_engine(f'postgresql://postgres:postgres@localhost:5432')
conn = engine.connect()
'''
conn.execute("commit")
conn.execute("CREATE DATABASE {0}".format('apple_db'))
conn.execute("commit")
'''
# Out:
# '\ndb = "apple_db"\nengine = create_engine(f\'postgresql://postgres:postgres@localhost:5432\')\nconn = engine.connect()\nconn.execute("commit")\nconn.execute("CREATE DATABASE {0}".format(\'apple_db\'))\nconn.execute("commit")\n'

# %%
meta = MetaData()
for c in Categorias:
    
    globals()[c+"_tbl"] = Table(
        c+'_tbl', meta,
        Column('id', Integer, primary_key=True),
        Column('track_name', String),
        Column('size_bytes', Integer),
        Column('currency', String),
        Column('price', String),
        Column('rating_count_tot', String),
        Column('user_rating', String),
        Column('prime_genre', String)
    )
    
meta.create_all(engine)
for c in Categorias:
    try:
        globals()[c].to_sql(name=globals()[c+'_tbl'], con=engine, if_exists='append', index=True)
    except:
        print('done')

for Categoria in Categorias:
    globals()[Categoria]=df.loc[df['prime_genre']==Categoria,:]
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %%
engine.table_names()
# Out:
# ['Book_&_Reference_tbl',
#  'Business_tbl',
#  'Catalogs_tbl',
#  'Education_tbl',
#  'Entertainment_tbl',
#  'Finance_tbl',
#  'Food_&_Drink_tbl',
#  'Games_tbl',
#  'Health_&_Fitness_tbl',
#  'Lifestyle_tbl',
#  'Medical_tbl',
#  'Music_tbl',
#  'Navigation_tbl',
#  'News_tbl',
#  'Photo_&_Video_tbl',
#  'Productivity_tbl',
#  'Shopping_tbl',
#  'Social_Networking_tbl',
#  'Sports_tbl',
#  'Travel_tbl',
#  'Utilities_tbl',
#  'Weather_tbl']

# %%
# %who DataFrame
# Out:
# Book_&_Reference	 Business	 Catalogs	 Education	 Entertainment	 Finance	 Food_&_Drink	 Games	 Health_&_Fitness
# Lifestyle	 Medical	 Music	 Navigation	 News	 Photo_&_Video	 Productivity	 Shopping	 Social_Networking
# Sports	 Travel	 Utilities	 Weather	 df
